# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
filefolder = os.getcwd()
print(filefolder)
# print(os.listdir(filefolder))
ext = ('.csv')
# Out:
# /home/erinay/racecar_docker/home/racecar_ws/bag_files

# %%
for files in os.listdir(filefolder):
    if files.endswith(ext):
        data = pd.read_csv(files)
        title = os.path.splitext(files)[0]
        ax=data.plot.scatter(x='%time',y='field.data')
        ax.set_xlabel('Time')
        ax.set_ylabel('Error Distance from Wall(m)')
        ax.set_title(title)

        img_file_loc= os.path.splitext(os.path.abspath(files))[:-1]
        print(image_file_loc)
        # plt.savefig('')

        # plt.show()
# Out:
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/right_corner.csv
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/kp2kd08.csv
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/kp5_oscil.csv
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/kp56_kd2.csv
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/kp24_kd03.csv
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/kp56_kd07.csv
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/kp25.csv
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/kp3oscil.csv
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/double_speed_halfed_k.csv
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/kp4_crash.csv
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/kp2kd07.csv
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/kp24_kd1.csv
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# ...
