# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
filefolder = os.getcwd()
print(filefolder)
# print(os.listdir(filefolder))
ext = ('.csv')
# Out:
# /home/erinay/racecar_docker/home/racecar_ws/bag_files/loc_error_pos

# %%
for files in os.listdir(filefolder):
    print(files)
    if files.endswith(ext):
        try:
            data = pd.read_csv(files)
        except:
            continue
        data = data[450:]
        title = os.path.splitext(files)[0]
        ax=data.plot.line(x='%time',y='field.data')
        ax.set_xlabel('Time')
        ax.set_ylabel('Error (m)')
        ax.set_title('Odometry Position Error from True Value with Gaussian Noise')
        new_img = filefolder+'/plot_img/'+title+'.png'
        plt.savefig(new_img)

        # plt.show()
# Out:
# make_visuals.ipynb
# no_noise_411.csv
# convert_bag.sh
# plot_img
# 411_smooth_sim.csv
# converted_bag
# no_noise_pos_error.csv
# noise_025_05.csv
# noise05.csv
# .ipynb_checkpoints
